# %% [markdown]
# # This notebook is attempting to split geojson into a pandas dataframe such that is then easier to use scikitlearn machine learning to identify bad vs. good data points on map. I.E. identify false positives.

# %% [markdown]
# started March 23rd, 2017

# %%
#### Imports for parts #1 & #2
# from bs4 import BeautifulSoup # For HTML parsing
from urllib.request import urlopen
import re # Regular expressions
from time import sleep # To prevent overwhelming the server between connections
from collections import Counter # Keep track of our term counts
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'
import pandas as pd # For converting results to a dataframe and bar chart plots
# %matplotlib inline
import json
import csv

##### Import modules for google API and geoJSON parts. Only duplicate is json
import requests
import configparser
import json
import geojson
from geojson import Point, Feature, FeatureCollection
# https://github.com/frewsxcv/python-geojson
import time
import pandas as pd

# %% [markdown]
# ### Load in geojsons & strip down to a list of features in json form

# %%
def load_geojson_as_df_old(path_for_geojson):
    df = pd.read_json(path_for_geojson)
    #print(df.FeatureCollection)
    #print("dataframe",df)
    print(df.columns)
    df_new = pd.DataFrame()
    for row in df.iterrows():
        print("row is ",row)
        df_new['features']
    #for each in df:
    #    print("each =",each)
        #df_new['features'] = each
    print("df_new =", df_new)
    feature_values = df.values
    print(feature_values)

# %%
def load_geojson_as_df(path_for_geojson):
    df = pd.read_json(path_for_geojson)
    #print(df.FeatureCollection)
    #print("dataframe",df)
    print("df.columns",df.columns)
    print("df[features]",df.geometry)
    
    df_new = df.drop('type',axis=1)
    print("df[features]",df_new)
    print("df_new",df_new)
    #print(df.columns)
    print("type",type(df_new[:1]))
    testZ = df_new[5:6]
    print("testZ properties",testZ)
    print("properties",df_new[5:6])
    return df_new

# %%
path_for_geojson = "../../DATA/test_geojson_Everything_1of3_v2.geojson"

# %%
df_new = load_geojson_as_df(path_for_geojson)
# Out:
# df.columns Index(['features', 'type'], dtype='object')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-4e1b8bcc2a2f> in <module>()
# ----> 1 df_new = load_geojson_as_df(path_for_geojson)
#
# <ipython-input-90-282cea50d2f4> in load_geojson_as_df(path_for_geojson)
#       4     #print("dataframe",df)
#       5     print("df.columns",df.columns)
# ----> 6     print("df[features]",df.geometry)
#       7
#       8     df_new = df.drop('type',axis=1)
#
# ~/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'geometry'

# %%
import fiona; fiona.supported_drivers
# Out:
# {'ARCGEN': 'r',
#  'AeronavFAA': 'r',
#  'BNA': 'raw',
#  'DGN': 'raw',
#  'DXF': 'raw',
#  'ESRI Shapefile': 'raw',
#  'GPKG': 'rw',
#  'GPSTrackMaker': 'raw',
#  'GPX': 'raw',
#  'GeoJSON': 'rw',
#  'Idrisi': 'r',
#  'MapInfo File': 'raw',
#  'OpenFileGDB': 'r',
#  'PCIDSK': 'r',
#  'SEGY': 'r',
#  'SUA': 'r'}

# %%
df_new
# Out:
#                                                features
# 0     {'type': 'Feature', 'geometry': {'type': 'Poin...
# 1     {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2     {'type': 'Feature', 'geometry': {'type': 'Poin...
# 3     {'type': 'Feature', 'geometry': {'type': 'Poin...
# 4     {'type': 'Feature', 'geometry': {'type': 'Poin...
# 5     {'type': 'Feature', 'geometry': {'type': 'Poin...
# 6     {'type': 'Feature', 'geometry': {'type': 'Poin...
# 7     {'type': 'Feature', 'geometry': {'type': 'Poin...
# 8     {'type': 'Feature', 'geometry': {'type': 'Poin...
# 9     {'type': 'Feature', 'geometry': {'type': 'Poin...
# 10    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 11    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 12    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 13    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 14    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 15    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 16    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 17    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 18    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 19    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 20    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 21    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 22    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 23    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 24    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 25    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 26    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 27    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 28    {'type': 'Feature', 'geometry': {'type': 'Poin...
# 29    {'type': 'Feature', 'geometry': {'type': 'Poin...
# ...                                                 ...
# 2860  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2861  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2862  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2863  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2864  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2865  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2866  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2867  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2868  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2869  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2870  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2871  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2872  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2873  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2874  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2875  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2876  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2877  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2878  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2879  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2880  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2881  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2882  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2883  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2884  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2885  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2886  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2887  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2888  {'type': 'Feature', 'geometry': {'type': 'Poin...
# 2889  {'type': 'Feature', 'geometry': {'type': 'Poin...
#
# [2890 rows x 1 columns]

# %%
#### this function takes a list of paths for different geojsons, opens each one, and dumps features into a single dataframe
def load_geojsonS_as_df(list_paths_geojsons,list_for_features):
    df = pd.read_json(path_for_geojson)
    feature_values = df.values
    print(feature_values)

# %% [markdown]
# ### Combine the three geojson (now in list of features form) into a single one

# %% [markdown]
# ### Turn each item into row of data frame & further split some columns into multiple columns

# %% [markdown]
# ### Export as csv and add a column ...
