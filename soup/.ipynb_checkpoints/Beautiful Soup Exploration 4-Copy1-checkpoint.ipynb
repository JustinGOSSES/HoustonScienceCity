# %% [markdown]
# # Single Notebook With All the Code to Go From List of Science Job Titles to geoJSON of Companies advertising those jobs on a map

# %% [markdown]
# ------------------------------------------------

# %% [markdown]
# # General Outline
# ### get list of science related jobs
#     * Clean up a list of science related job titles I modified from wikipedia in excel, save as csv
# ### get company names that are hiring for those science related job titles in Houston, TX by scraping job search site(s)
#     * use beautiful soup, a python library to gather information from websites programtically and return list of companies
#     * Clean up duplication and companies that shouldn't be included
# ### get addresses and lat longs associated with each company name in json form
#     * use google places API to search for company name and a Houston, TX location, returning json of location and company information
#     * clean returned list of json data such that it is limited to a lat long box of the greater houston area
#     * clean up duplicates and are false positives useing pandas and other python libraries to
# ### convert results to geoJSON. Add-in additional data dimensions, such as job title used in seach, as geoJSON properties
#     * use geoJSON and JSON python libraries to convert previous json into points, and then features, and then a single feature collection
# ### get geoJSONs from other sources that contain science location data on things like schools and hospitals
#     * use .... a http get call to access the geoJSON files already created by the city of Houston.
# ### add geoJSONs to map. Use color, size, and shape to represent different geoJSON properties. Tell a story
#     * use mapboxGL.js, leaflet.js, and basic html/CSS/JS to create maps

# %% [markdown]
# ### importing needed python modules

# %%
#### Imports for parts #1 & #2
from bs4 import BeautifulSoup # For HTML parsing
from urllib.request import urlopen
import re # Regular expressions
from time import sleep # To prevent overwhelming the server between connections
from collections import Counter # Keep track of our term counts
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'
import pandas as pd # For converting results to a dataframe and bar chart plots
# %matplotlib inline
import json
import csv

##### Import modules for google API and geoJSON parts. Only duplicate is json
import requests
import configparser
import json
import geojson
from geojson import Point, Feature, FeatureCollection
# https://github.com/frewsxcv/python-geojson
import time
import pandas as pd

# %% [markdown]
# ===================================================================================
#
# # 1. Load list of job titles

# %% [markdown]
# ------------------------------------------------------------------------------

# %%
with open('../Data/science_jobs_v2.csv', 'rt') as f:
    reader = csv.reader(f)
    science_jobs_list_withInfo = list(reader)

job_title_list = []
for each in science_jobs_list_withInfo:
    each = each[0]
    #print('each',each)
    job_title_list.append(each)

# take out the header 'Job_Title'
job_title_list.pop(0)

print(job_title_list)
# Out:
# ['Bioanalytical Scientist', 'Biochemist', 'Biochemistry', 'Bioinformatics Research Scientist', 'Biological Engineer', 'Biologist', 'biology  ', 'biomechanical', 'Biomedical scientist', 'biophysics', 'Cell Line', 'Clinical Data', 'Clinical Data Research', 'Clinical Pharmacology Professor', 'Clinical Pharmacy Assistant', 'Clinical Research Associate', 'Drug Evaluator', 'Drug Regulatory Affairs Manager', 'Environmental Health Scientist', 'Genetic Counselor', 'Health Research', 'Health Technology', 'Healthcare science', 'Hospital Research Assistant', 'Immunology Scientist', 'Life Science', 'Medical', 'Medical Center', 'medical Laboratory', 'Medical laboratory scientist', 'Medical Physics Researcher', 'Medical Research Assistant', 'Medical Research Technician', 'Medical Scientist', 'Microbiologist', 'Molecular Biologist', 'Molecular physics', 'Neuroscientist', 'Nuclear', 'Oncology Researcher', 'Pathologist', 'Pharmaceutical Assistant', 'Pharmaceutical Research Analyst', 'Pharmaceutical Research Assistant', 'Pharmaceutical Technician', 'Pharmacy Assistant', 'Photochemistry', 'Public Health Specialist', 'radiobiology', 'Radiochemistry', 'Toxicologist', 'Agricultural', 'Archaeologist', 'Associate Professor', 'Botanist', 'botany', 'Chemical', 'Chemist', 'Climate Data', 'Conservation', 'Field Technician', 'Forensic Chemist', 'Forensic Scientist', 'Herpetologist', 'Laboratory Instructor', 'Laboratory Technician', 'meteorologist ', 'Natural Science', 'Naturalist', 'Oceanographer', 'oceanography', 'optomitrist ', 'Physical Scientist', 'Psychologist', 'Research and Development Associate', 'Research and Development Director', 'Research and Development Manager', 'Research and Development Supervisor', 'Research and Development Technician', 'Research and Innovation', 'Research Fellow', 'Research Scientist', 'Researcher', 'science intern', 'Science teacher', 'Science Writer', 'Scientist', 'social science', 'Solid-state', 'STEM Career Advisor', 'Stem Cell Researcher', 'Stereochemistry', 'Structural Biologist', 'Theoretical', 'Volcanologist', 'volcanology', 'wind power', 'wind turbine ', 'zoo', 'Zoologist', 'zoology ', 'chemistry', 'Crystallography', 'Earth Science', 'Ecologist', 'Ecology', 'Environmental', 'Environmental Emergencies', 'Environmental Research Assistant', 'Environmental Specialist', 'Exploration', 'fluid dynamics', 'geochemist', 'Geochemistry', 'Geographer', 'Geologist', 'geology ', 'geophysicist', 'GiS ', 'Groundwater Technician', 'hydrology', 'Inorganic', 'lab technician', 'Materials science', 'micropaleontologist', 'operations geologist', 'paleoclimatology', 'paleoecology', 'Paleontologist', 'Petroleum geologist', 'petrophysicist', 'playnology', 'Research and Development Chemist', 'Research Chemist', 'reservoir engineer', 'reservoir modeler', 'rock Laboratory', 'sedimentologist', 'stratigraphy', 'subsea engineer', 'aeronautics', 'Aerospace', 'astrobiology', 'Astrochemistry', 'astromaterials', 'Astronaut', 'Astronomer', 'astronomy', 'astrophysics', 'Food chemistry', 'heliophysics', 'International Space Station', 'Johnson Space Center', 'lunar', 'materials engineer', 'NASA', 'Physicist', 'physics', 'Planetary  ', 'planetary geology', 'propulsion engineer', 'Satellite', 'space engineer', 'Space science', 'telemetry']

# %%
short_job_title_list_old1stHalf = ['Biochemistry', 'Bioinformatics', 'Biologist', 'biomechanical', 'Biomedical', 'biophysics', 'Cell+Line', 'Clinical+Data', 'Pharmacology', 'Pharmacy', 'Drug Evaluator', 'Environmental Health', 'Genetic Counselor', 'Healthcare', 'Hospital', 'Immunology', 'Life Science', 'Medical', 'Medical Center', 'medical Laboratory', 'Medical Physics', 'Medical', 'Microbiologist', 'Neuroscientist', 'Nuclear', 'Oncology', 'Pathologist', 'Pharmaceutical', 'Photochemistry', 'Public Health Specialist', 'radiobiology', 'Radiochemistry', 'Toxicologist', 'Agricultural', 'Archaeologist', 'Associate Professor', 'Botanist', 'botany', 'Chemical', 'Chemist', 'Conservation', 'Forensic Chemist', 'Herpetologist', 'Laboratory', 'meteorologist ', 'Naturalist', 'Oceanographer', 'oceanography', 'optomitrist']

# %%
short_job_title_list_1stHalf = ['Chemist', 'Conservation', 'Forensic Chemist', 'Herpetologist', 'Laboratory', 'meteorologist ', 'Naturalist', 'Oceanographer', 'oceanography', 'optomitrist']

# %%
len(short_job_title_list_old1stHalf)
# Out:
# 49

# %%
short_job_title_list_2ndHalf = ['Forensic Scientist','Physical Scientist','Psychologist', 'Research Fellow', 'Science teacher', 'Scientist', 'social science', 'Solid-state', 'STEM', 'Stem Cell', 'Stereochemistry', 'Volcanologist', 'volcanology', 'wind power', 'wind turbine ', 'zoo', 'Zoologist', 'zoology ', 'chemistry', 'Crystallography', 'Earth Science', 'Ecologist', 'Ecology', 'Environmental', 'Exploration', 'fluid dynamics', 'geochemist', 'Geochemistry', 'Geographer', 'Geologist', 'geology ', 'geophysicist', 'GiS ', 'Groundwater Technician', 'hydrology', 'Inorganic', 'lab technician', 'Materials science', 'micropaleontologist', 'operations geologist', 'paleoclimatology', 'paleoecology', 'Paleontologist', 'Petroleum geologist', 'petrophysicist', 'playnology', 'reservoir', 'modeler', 'rock Laboratory', 'sedimentologist', 'stratigraphy', 'subsea', 'aeronautics', 'Aerospace', 'astrobiology', 'Astrochemistry', 'astromaterials', 'Astronaut', 'Astronomer', 'astronomy', 'astrophysics', 'Food chemistry', 'heliophysics', 'International Space Station', 'Johnson Space Center', 'lunar', 'materials', 'NASA', 'Physicist', 'physics', 'Planetary', 'propulsion engineer', 'Satellite', 'Space science', 'telemetry']

# %%
len(short_job_title_list_2ndHalf)
# Out:
# 75

# %%
test_short_job_title_list = ['Chemist', 'Conservation', 'Herpetologist', 'Laboratory', 'meteorologist ', 'Naturalist']

# %%
len(test_short_job_title_list)
# Out:
# 6

# %%
# replace some of the characters so the search is a bit better:
def cleanCompanies(company_array):
    new_array = []
    for each in company_array:
        #print(each, "and type is ",type(each))
        print(each.find("-",0))
        print(type(each.find("-",0)),"type of each.find('-',0")
        #print(type(each.find("%2C",1)))
        if each.find("%2C",1) is not -1:
            each = each.replace("%2C",",")
            print(each,"= each")
        else:
            each = each
        if each.find("%26",1) is not -1:
            each = each.replace("%26","&")
            #print(each,"= each find")
        else:
            each = each
        ##print(each, "again with each")
        if  each.find("-1",1) is not -1:
            each = each.replace("-1","")
        #    print(each,"= each find")
        else:
            each = each
        if  each.find("-2",0) is not -1:
            each = each.replace("-2","")
            print(each,"= each find")
        else: 
            each = each
        if  each.find("-3",0) is not -1:
            each = each.replace("-3","")
        #    print(each,"= each find")
        else:
            each
        if  each.find("-",1) is not -1:
            each = each.replace("-","+")
            print(each,"= each find")
        else:
            each = each
        if  each.find(" ",1) is not -1:
            each = each.replace(" ","+")
            print(each,"= each find")
        else:
            each = each
        print("each at end",each)
        new_array.extend([each])
    print('new_array',new_array)
    return new_array

# %% [markdown]
# ------------------------------------------------------------------------------
# # 2. Get company names that are hiring for those science related job titles in Houston, TX by scraping job search site(s)
# ------------------------------------------------------------------------------

# %% [markdown]
# =========================================================================================
# ## A data exploration using beautiful soup
# - based on this: https://jessesw.com/Data-Science-Skills/

# %% [markdown]
# ### The function 'skills_info' takes three arguments; city, state, and job title and returns a list of companies searching for that job title in the last 30 days in Houston, TX

# %%
def skills_info(city="Houston", state="TX",job_title='data+scientist'):
    '''
    This function will take a desired city/state and look for all new job postings
    on Indeed.com. It will crawl all of the job postings and keep track of how many
    use a preset list of typical data science skills. The final percentage for each skill
    is then displayed at the end of the collation. 
        
    Inputs: The location's city and state. These are optional. If no city/state is input, 
    the function will assume a national search (this can take a while!!!).
    Input the city/state as strings, such as skills_info('Chicago', 'IL').
    Use a two letter abbreviation for the state.
    '''
    #print("test1")   
    final_job = job_title # searching for data scientist exact fit("data scientist" on Indeed search)
    
    # Make sure the city specified works properly if it has more than one word (such as San Francisco)  %22&l=
    if city is not None:
        final_city = city.split() 
        final_city = '+'.join(word for word in final_city)
        final_site_list = ['https://www.indeed.com/jobs?q=', final_job, '&l=', final_city,'%2C+', state] # Join all of our strings together so that indeed will search correctly
    else:
        final_site_list = ['https://www.indeed.com/jobs?q="', final_job, '"']

    final_site = ''.join(final_site_list) # Merge the html address together into one string

    # website query today (2017-02-25) is = https://www.indeed.com/jobs?q=data+scientist&l=Houston%2CTX
        
    base_url = 'http://www.indeed.com'
    
    #print("test2")  
    try:
        html = urlopen(final_site).read() # Open up the front page of our search first
    except:
        #print('That city/state combination did not have any jobs. Exiting . . .') # In case the city is invalid
        return
    soup = BeautifulSoup(html,"lxml") # Get the html from the first page
    
    # Now find out how many jobs there were
    
    if type(soup.find(id = 'searchCount')) is None or type(soup.find(id = 'searchCount')) == None:
        c
    
    else:
        variableS = soup.find(id = 'searchCount')
        if isinstance(variableS,type(None)):
            all_company_results = []
            return all_company_results
        else:
            print("soup.find(id = 'searchCount') = ",soup.find(id = 'searchCount'))
            print("soup.find(id = 'searchCount') = ",type(soup.find(id = 'searchCount')))

            num_jobs_area = soup.find(id = 'searchCount').string.encode('utf-8') # Now extract the total number of jobs found
                                                                                # The 'searchCount' object has this
            #print('num_jobs_area before filtering ', num_jobs_area)

            job_numbers = re.findall(b'\d+', num_jobs_area) # Extract the total jobs found from the search result

            #print('job number before filtering ', job_numbers[2])

            job_numbers_decoded = int(job_numbers[2].decode('utf-8'))
            #print('job_numbers_decoded = ',job_numbers_decoded, "type is ",type(job_numbers_decoded))

            #if len(job_numbers[2]) > 3: # Have a total number of jobs greater than 1000
            #    total_num_jobs = (int(job_numbers[2])*1000) + int(job_numbers[3])
            #else:
            #    total_num_jobs = int(job_numbers[2]) 

            total_num_jobs = job_numbers_decoded

            city_title = city
            if city is None:
                city_title = 'Nationwide'

            #print('There were', total_num_jobs, 'jobs found,', city_title) # Display how many jobs were found

            # took out /10 here, which seemed to be assuming always 10 results per page? now 15?
            num_pages = int(float(total_num_jobs/10)) # This will be how we know the number of times we need to iterate over each new
                                              # search result page

            job_descriptions = [] # Store all our descriptions in this list

            # used to be 'xrange' here but I changed it to 'range' because I'm using python3 and xrange is python2 only
            all_company_results = []
            for i in range(1,num_pages+1): # Loop through all of our search result pages
                #print('Getting page', i)

                start_num = str(i*10) # Assign the multiplier of 10 to view the pages we want
                current_page = ''.join([final_site, '&start=', start_num])
                # Now that we can view the correct 10 job returns, start collecting the text samples from each

                html_page = urlopen(current_page).read() # Get the page

                page_obj = BeautifulSoup(html_page,"lxml") # Locate all of the job links
                job_link_area = page_obj.find(id = 'resultsCol') # The center column on the page where the job postings exist
                #print('page_obj',page_obj)  

                #print("link.get('href')",base_url + link.get('href')
                #print("job_link_area.find_all('a')",job_link_area.find_all('a'))

                for a in job_link_area.find_all('a', href=True):
                    #print ("Found the URL:", a['href'])
                    if "/cmp/" in a['href']: 
                        #  if a['href'].find("/cmp/"):
                        #print("a had /cmp/ in it using find = ",a['href'])
                        arrayHrefParts_0 = a['href'].split('/cmp/')
                        #print("aarrayHrefParts_0 = ",arrayHrefParts_0)
                        arrayHrefParts_1 = arrayHrefParts_0[1].split('/')
                        #print("arrayHrefParts_1 = ",arrayHrefParts_1)
                        company = arrayHrefParts_1[0]
                        #print('company = ',company)
                        all_company_results.append(company)
                        #print('all_company_results =',all_company_results)
                    else:
                        continue
                        #print("/cmp/ not found in ,",a['href'])

                #print("[base_url + link.get('href') for link in job_link_area.find_all('a')]",[base_url + link.get('href') for link in job_link_area.find_all('a')])

                #job_URLS = [base_url + link.get('href') for link in job_link_area.find_all('a')] # Get the URLS for the jobs

                #job_URLS = filter(lambda x:'clk' in x, job_URLS) # Now get just the job related URLS


                #         for j in xrange(0,len(job_URLS)):
                #             final_description = text_cleaner(job_URLS[j])
                #             if final_description: # So that we only append when the website was accessed correctly
                #                 job_descriptions.append(final_description)
                #             sleep(1) # So that we don't be jerks. If you have a very fast internet connection you could hit the server a lot! 

                sleep(1) # So that we don't be jerks. If you have a very fast internet connection you could hit the server a lot! 

            for each in range(len(all_company_results)):
                if '.html' in all_company_results[each]:
                    #print('all_company_results[each]',all_company_results[each]," each = ",each)
                    new_name_wo_html = all_company_results[each].split('.html')[0]
                    #print('new_name_wo_html',new_name_wo_html)
                    all_company_results[each] = new_name_wo_html  

            all_company_results = list(set(all_company_results))
            #print ('Done with collecting the job postings!')    
            #print ('all_company_results final = ',all_company_results)
            #print ("There were",len(all_company_results)," companies successfully found.")
            all_company_results_json = []
            for each in all_company_results:
                print("each in all_company_results = ",each)
                print("job_title in all_company_results = ",job_title)
                temp_obj_holder = {"company":"nothing","job_title":"nothing"}
                print("temp_obj_holder = ",temp_obj_holder)
                temp_obj_holder["job_title"] = job_title
                temp_obj_holder["company"] = each
                print("temp_obj_holder['job_title'] = ",temp_obj_holder["job_title"])
                all_company_results_json.append(temp_obj_holder)
            return all_company_results_json

# %% [markdown]
# ### The function 'runMultiple_skills_info' runs the 'skills_info' function multiple times, one for each job title in the list given to 'runMultiple_skills_info' function

# %%
def runMultiple_skills_info(array_of_jobTitles=['puppies']):
    all_results = []
    for each in array_of_jobTitles:
        print('each= ',each)
        #temp_results1 = []
        temp_results1 = skills_info("Houston","TX",each)
        if temp_results1 is None:
            continue
        else:
            print('temp_results is ',temp_results1)
            #all_results.extend(temp_results1) 
            all_results.extend(temp_results1)
    return all_results

# %%
def saveArray_of_JobSearchResults(arrayOfJobsAndSearchTerm, FilePath):
    toCSV = arrayOfJobsAndSearchTerm
    keys = toCSV[0].keys()
    with open(FilePath, 'w') as output_file:
        dict_writer = csv.DictWriter(output_file, keys)
        dict_writer.writeheader()
        dict_writer.writerows(toCSV)
    return arrayOfJobsAndSearchTerm

# %% [markdown]
# #### Review:
#
# 3 functions:
# - A. skills_info(city="Houston", state="TX",job_title='data+scientist')
# - B. runMultiple_skills_info(array_of_jobTitles=['puppies'])
# - C. saveArray_of_JobSearchResults(arrayOfJobsAndSearchTerm = geo_and_geo, FilePath ='../DATA/someFile')
#
# A does the web scraping. B does web scraping searching for each of the items in the input array and combines the resuls. C saves the results as a csv file with two columns. One column header is Job Title used in search. The other column is company name looking for that job title in Houston Texas.

# %% [markdown]
# ------------------------------------------------------------------------------
# # 3. Get addresses and lat longs associated with each company name in json form
# ------------------------------------------------------------------------------

# %% [markdown]
# ### Modules imported at top of this notebook

# %% [markdown]
# ### using <a href="https://docs.python.org/3/library/configparser.html">configparser</a> to handle config file

# %%
config = configparser.ConfigParser()

# %%
configFilePath = '../config.conf'
# configparser.ConfigParser().read(configFilePath)
config.read(configFilePath)
# Out:
# ['../config.conf']

# %% [markdown]
# ### next block sets a variety of useful variables used in the google places API

# %%
#### sets key as variable that contains the google-places-api key
key = config['google-places-api']['key1']
#### creates a string used as the prefix to the key in the url used in calling the API service
key_pre = '&key='
#### the base url in the google places API get call
base_url = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query='
#### the base url when calling a next page, in other words, when results are more than 20
next_page_base_url = 'https://maps.googleapis.com/maps/api/place/textsearch/json?'

# %%
# replace some of the characters so the search is a bit better:
def cleanCompanies(company_array):
    company_array = company_array[1:]
    new_array = []
    for each in company_array:
        job_title = each[1]
        each = each[0]
        #print(each, "and type is ",type(each))
        print(each.find("-",0))
        print(type(each.find("-",0)),"type of each.find('-',0")
        #print(type(each.find("%2C",1)))
        if each.find("%2C",1) is not -1:
            each = each.replace("%2C",",")
            print(each,"= each")
        else:
            each = each
        if each.find("%26",1) is not -1:
            each = each.replace("%26","&")
            #print(each,"= each find")
        else:
            each = each
        ##print(each, "again with each")
        if  each.find("-1",1) is not -1:
            each = each.replace("-1","")
        #    print(each,"= each find")
        else:
            each = each
        if  each.find("-2",0) is not -1:
            each = each.replace("-2","")
            print(each,"= each find")
        else: 
            each = each
        if  each.find("-3",0) is not -1:
            each = each.replace("-3","")
        #    print(each,"= each find")
        else:
            each = each
        if  each.find("-",1) is not -1:
            each = each.replace("-","+")
            print(each,"= each find")
        else:
            each = each
        print("each at end",each)
        new_array.extend([[each,job_title]])
    print('new_array',new_array)
    return new_array

# %% [markdown]
# ### All the functions that load and clean the company + job title list from csv into memory

# %%
def load_listCompanyJobtitle(path):
    df=pd.read_csv(path,header=None)
    company_array = df.values
    company_array_formatted = cleanCompanies(company_array)
    return company_array_formatted

# %% [markdown]
# ### Next few functions run the company names through the google places API

# %% [markdown]
# ##### Below is the main function that calls the Google Places API to get the initial results

# %%
# function that takes a datset that is 
def callGooglePlacesAPI(search_term,nameOfSearch,job_title):
    print('job_title put into googleAPI call is =',job_title)
    dataset_I = requests.get(base_url+search_term+key_pre+key)
    next_page_result = []
    try:
        next_page_token = dataset_I.json()['next_page_token']
        next_page_result = callNextPageResults(nameOfSearch,next_page_token,job_title)
    except: 
        pass
    #####if 'next_page_token' in dataset_I:
    #next_page_token = dataset_I.json()['next_page_token']
    #print("next_page_token",next_page_token)
    #callNextPageResults(nameOfSearch,next_page_token)
    #####next_page_results = makeFeatureCollectionsFromPlaces(dataset_I['next_page_token'],nameOfSearch).json()['results']
    ##### #else: 
    ####    next_page = "none needed"
    dataset = dataset_I.json()['results']
    #if 'next_page_token' in dataset_I:
    #    dataset.extend(next_page_results)
    #    print("dataset up top",dataset)
    #else:
    #    next_page = "none needed"
    array_of_features = []
    for each in dataset:
        photos = []
        # centerpoint for coordinates
        #print(each)
        lat = each['geometry']['location']['lat']
        long = each['geometry']['location']['lng']
        # properties
        address = each['formatted_address']
        id = each['id']
        name = each['name']
        # photos is an array
        try:
            photos = each['photos']
        except:
            photos = []
            #print("photos , attribute error but kept going")
        place_id = each['place_id']
        try:
            rating = each['rating']
        except:
            rating = 'NA'
            #print("rating , attribute error but kept going")
        reference = each['reference']
        # types is an array
        types = each['types']
        testPoint = Point((long, lat))
        test2_geoJSOn = Feature(geometry=testPoint, properties={"job_title":job_title,"name": name,"address":address,"id":id,"photos":photos,"place_id":place_id,"rating":rating,"reference":reference,"types":types})
        array_of_features.extend([test2_geoJSOn])
#     new_FeatureCollection = FeatureCollection(array_of_features) 
#     with open('../DATA/'+nameOfSearch+'_test.geojson', 'w') as f:
#         json.dump(new_FeatureCollection, f)
#     return new_FeatureCollection
    print("array_of_features = ",array_of_features," and next_page_result = ",next_page_result)
    print("types: for "+search_term+" type(next_page_result)= ",type(next_page_result)," and type(array_of_features)=  ",type(array_of_features))
    if next_page_result is None or next_page_result==[]:
        fakeVariable = 3
        #print("no second page")
    else:
        #print("next_page_result passed none test and is ",next_page_result)
        array_of_features.extend(next_page_result)
        #print("array_of_features after extension = ",array_of_features)
    #print("2nd statement of array_of_features = ",array_of_features)
    return array_of_features

# %% [markdown]
# ##### Below is a secondary function that calls the Google Places API "next page" to get any results further additional to the first 40.

# %%
def callNextPageResults(nameOfSearch,keyForNextPage,job_title):
    time.sleep(5)
    #print('next_page_base_url+"&pagetoken="+keyForNextPage+key_pre+key =',next_page_base_url+"pagetoken="+keyForNextPage+key_pre+key)
    dataset_I = requests.get(next_page_base_url+"pagetoken="+keyForNextPage+key_pre+key)
    #print("dataset_I second page full response",dataset_I.json())
    dataset = dataset_I.json()['results']
    array_of_features = []
    for each in dataset:
        photos = []
        # centerpoint for coordinates
        #print(each)
        lat = each['geometry']['location']['lat']
        long = each['geometry']['location']['lng']
        # properties
        address = each['formatted_address']
        id = each['id']
        name = each['name']
        # photos is an array
        try:
            photos = each['photos']
        except:
            photos = []
            #print("photos , attribute error but kept going")
        place_id = each['place_id']
        try:
            rating = each['rating']
        except:
            rating = 'NA'
            #print("rating , attribute error but kept going")
        reference = each['reference']
        # types is an array
        types = each['types']
        testPoint = Point((long, lat))
        test2_geoJSOn = Feature(geometry=testPoint, properties={"job_title":job_title,"name": name,"address":address,"id":id,"photos":photos,"place_id":place_id,"rating":rating,"reference":reference,"types":types})
        array_of_features.extend([test2_geoJSOn])
    #new_FeatureCollection = FeatureCollection(array_of_features) 
    #with open('../DATA/'+nameOfSearch+'_2ndPage_test.geojson', 'w') as f:
    #    json.dump(new_FeatureCollection, f)
    #print("second page results = ",new_FeatureCollection)
    #return new_FeatureCollection
    return array_of_features

# %% [markdown]
# ##### Below is the a function that runs through a list and calls the two functions above and combines the results into a single result

# %%
def create_List_Features(cp_array_formatted):
    array_of_all_features = []
    print("in function create_List_Features, cp_array_formatted[0][0]",cp_array_formatted[0][0])
    for each in cp_array_formatted:
        #try:
        features_1 = callGooglePlacesAPI(each[1]+"+Houston+Texas","random_for_now",each[0])
        #print("features for a company name =",features_1)
        if array_of_all_features == [] or array_of_all_features is None:
            array_of_all_features = features_1
        else:
            if features_1 is None or features_1 == []:
                pass
            else:
                array_of_all_features.extend(features_1)
        #except:
        #    print("error in except",error)
        
        #print("array_of_all_features = ",array_of_all_features)
    
    return array_of_all_features

# %% [markdown]
# ##### function that takes a list of features and returns a feature collection

# %%
# creates feature collection from list of features
def createFeatureCollection(list_of_features,geographic_limits):
    slimmed_featList = []
    print('geographic_limits =',geographic_limits)
    for each in list_of_features:
        print("each = ",each)
        print("each['geometry']['coordinates']",each['geometry']['coordinates'])
        print("each['geometry']['coordinates'][0] =",each['geometry']['coordinates'][0])
        if each['geometry']['coordinates'][0] > geographic_limits["west_limit"] and each['geometry']['coordinates'][0] < geographic_limits["east_limit"] and each['geometry']['coordinates'][1] < geographic_limits["north_limit"] and each['geometry']['coordinates'][1] > geographic_limits["south_limit"]:
            slimmed_featList.append(each)
    
    
    print('finished the function createFeatureCollection and slimmed featureList is slimmed_featList',slimmed_featList)
    return FeatureCollection(slimmed_featList)

# %% [markdown]
# ##### function that takes the return from the above function and saves it as a geoJSON file

# %% [markdown]
#  30°15'6.44"N   96° 5'17.13"W
#   29°16'56.13"N  95°57'46.47"W
#    29°21'28.30"N   94°38'24.37"W
#     30°26'55.88"N   94°48'6.63"W
#
#     north limit = 30°26'55.88      30.44885556
#     south limit = 29°16'56.13"N     29.28225833
#     west limit = 96° 5'17.13"W     -96.08805556
#     east limit = 94°38'24.37"W     -94.64000000

# %%
# convert feature collection to geoJSON
def convertFeatureCollectionToGeoJSON(featCollection,fileNamePath):
    print('got to the function convertFeatureCollectionToGeoJSON')
    with open(fileNamePath, 'w') as f:
        json.dump(featCollection, f)

# %% [markdown]
# #### function that calls the others. It takes as arguments the list of companies and job_titles & the path to save the resulting geojson to

# %%
def make_geojson_from_CompanyJobList(company_list_formatted,path,geographic_limits):
    #### function that calls the google api and returns results in terms of a list of feature
    print("make_geojson_from_CompanyJobList(company_list_formatted = ",company_list_formatted)
    list_of_features = create_List_Features(company_list_formatted)
    #### function that creates a feature collection from the list of features
    featCollection = createFeatureCollection(list_of_features,geographic_limits)
    #### function that takes the feature collection and file path and saves the feature collection as a geoJSON file
    convertFeatureCollectionToGeoJSON(featCollection,path)
    return featCollection

# %% [markdown]
# ### The geographic limits that trim down the results to only things around Houston as some jobs are advertised in Houston that aren't located in Houston

# %%
geographic_limits = {"north_limit":30.454961,"south_limit":28.956857,"west_limit":-96.206159,"east_limit":-94.64000000}

# %% [markdown]
# ------------------------------------------------------------------------------
# ## Run Everything As Single Function
# ------------------------------------------------------------------------------

# %%
def getJSON_from_jobsList_everything(array_of_job_Titles,FilePath,path,geographic_limits):
    #### returns list of companies advertising each job in an array of job titles
    list_of_CompaniesAndJobs = runMultiple_skills_info(array_of_job_Titles)
    #### saves the list of lists from above... and formats it a bit further in prep for next step
    Array_of_JobCompany_edA = saveArray_of_JobSearchResults(list_of_CompaniesAndJobs, FilePath)
    print("in geoJSON_from_jobsList_everything, Array_of_JobCompany is =",Array_of_JobCompany_edA)
    ##### opens and cleans the list of companies 
    Array_of_JobCompany_cln = load_listCompanyJobtitle(FilePath)
    #### runs the companies through the google places API
    #### combines the results into an array of features
    #### turns that into a feature collection 
    #### then saves as geojson
    feature_collection = make_geojson_from_CompanyJobList(Array_of_JobCompany_cln,path,geographic_limits)
    #### returns the previously created feature collection for testing of result without reloading from geojson
    return feature_collection

# %% [markdown]
# Input_List_JobTitles = test_short_job_title_list
#
# FilePath = '../DATA/test_jobSearchTermAndCompany_all_v3.csv'
#
# path="../DATA/test_geojson_Everything_v3.geojson"
#
# geographic_limits ={"north_limit":30.454961,"south_limit":28.956857,"west_limit":-96.206159,"east_limit":-94.64000000}

# %%
funcArg = {"ListJobTitles":test_short_job_title_list,"pCSV":'../DATA/test_jobTitleCompany_all_v5.csv',"pGeoJSON":"../DATA/test_geojson_Everything_v5.geojson","geo_lim":{"north_limit":30.454961,"south_limit":28.956857,"west_limit":-96.206159,"east_limit":-94.64000000}}

# %%
answer3  = getJSON_from_jobsList_everything(funcArg["ListJobTitles"],funcArg["pCSV"],funcArg["pGeoJSON"],funcArg["geo_lim"])
# Out:
# each=  Chemist
# soup.find(id = 'searchCount') =  <div id="searchCount">Jobs 1 to 10 of 119</div>
# soup.find(id = 'searchCount') =  <class 'bs4.element.Tag'>
# each in all_company_results =  Texas-Children%27s-Hospital
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Chamberlain-College-of-Nursing
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  O%27rourke-Petroleum
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Lee-College
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Celanese
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  O'rourke-Petroleum
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Huntington-Learning-Center---Missouri-City,-Tx
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Amerisourcebergen
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Houston-Methodist
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  University-of-Houston
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  GE-Corporate
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Solvay
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Sgs
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Nalco-Champion,-An-Ecolab-Company
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Schlumberger
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Lonestar-College-System-1
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  North-American-Composites
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Intertek
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Stericycle
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Idexx-Laboratories
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Rice-University
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Stolt--nielsen-Limited
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  College-Nannies-%252B-Tutors
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Staffing-the-Universe
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Momentive-Specialty-Chemicals-2
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Assure-Oilfield-Testing,-Inc.-1
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Halliburton
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Labtopia-1
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  College-Nannies-%2B-Tutors
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Nes-Global-Talent
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  SAN-Jacinto-College
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Huntington-Learning-Center---Missouri-City%2C-Tx
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Clean-Harbors
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Doble-Engineering
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Lyondell
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Scholastic-Family-Tutoring
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Ascend-Performance-Materials
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Octapharma
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  St.-Joseph-Medical-Center
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Huntsman
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  The-Kinkaid-School
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Zimmerman-Medical-Clinic
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Kipp-Houston-Public-Schools
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Md-Anderson-Cancer-Center
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Devry-University
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Pcca
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Sysco
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Bureau-Veritas
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Clinical-Pathology-Laboratories
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Texas-Children's-Hospital
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Yes-Prep-Public-Schools
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Blue-Quality-Services
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Altus-Baytown-Hospital-2
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Nationwide-Laboratory-Partners-LLC
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Baylor-College-of-Medicine
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Search-Solution-Group
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Nalco-Champion%2C-An-Ecolab-Company
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  The-Princeton-Review
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Hexion-Inc.
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Houston-Baptist-University
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Tech-2000
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# each in all_company_results =  Adecco-USA-b5c07591
# job_title in all_company_results =  Chemist
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Chemist
# temp_results is  [{'job_title': 'Chemist', 'company': 'Texas-Children%27s-Hospital'}, {'job_title': 'Chemist', 'company': 'Chamberlain-College-of-Nursing'}, {'job_title': 'Chemist', 'company': 'O%27rourke-Petroleum'}, {'job_title': 'Chemist', 'company': 'Lee-College'}, {'job_title': 'Chemist', 'company': 'Celanese'}, {'job_title': 'Chemist', 'company': "O'rourke-Petroleum"}, {'job_title': 'Chemist', 'company': 'Huntington-Learning-Center---Missouri-City,-Tx'}, {'job_title': 'Chemist', 'company': 'Amerisourcebergen'}, {'job_title': 'Chemist', 'company': 'Houston-Methodist'}, {'job_title': 'Chemist', 'company': 'University-of-Houston'}, {'job_title': 'Chemist', 'company': 'GE-Corporate'}, {'job_title': 'Chemist', 'company': 'Solvay'}, {'job_title': 'Chemist', 'company': 'Sgs'}, {'job_title': 'Chemist', 'company': 'Nalco-Champion,-An-Ecolab-Company'}, {'job_title': 'Chemist', 'company': 'Schlumberger'}, {'job_title': 'Chemist', 'company': 'Lonestar-College-System-1'}, {'job_title': 'Chemist', 'company': 'North-American-Composites'}, {'job_title': 'Chemist', 'company': 'Intertek'}, {'job_title': 'Chemist', 'company': 'Stericycle'}, {'job_title': 'Chemist', 'company': 'Idexx-Laboratories'}, {'job_title': 'Chemist', 'company': 'Rice-University'}, {'job_title': 'Chemist', 'company': 'Stolt--nielsen-Limited'}, {'job_title': 'Chemist', 'company': 'College-Nannies-%252B-Tutors'}, {'job_title': 'Chemist', 'company': 'Staffing-the-Universe'}, {'job_title': 'Chemist', 'company': 'Momentive-Specialty-Chemicals-2'}, {'job_title': 'Chemist', 'company': 'Assure-Oilfield-Testing,-Inc.-1'}, {'job_title': 'Chemist', 'company': 'Halliburton'}, {'job_title': 'Chemist', 'company': 'Labtopia-1'}, {'job_title': 'Chemist', 'company': 'College-Nannies-%2B-Tutors'}, {'job_title': 'Chemist', 'company': 'Nes-Global-Talent'}, {'job_title': 'Chemist', 'company': 'SAN-Jacinto-College'}, {'job_title': 'Chemist', 'company': 'Huntington-Learning-Center---Missouri-City%2C-Tx'}, {'job_title': 'Chemist', 'company': 'Clean-Harbors'}, {'job_title': 'Chemist', 'company': 'Doble-Engineering'}, {'job_title': 'Chemist', 'company': 'Lyondell'}, {'job_title': 'Chemist', 'company': 'Scholastic-Family-Tutoring'}, {'job_title': 'Chemist', 'company': 'Ascend-Performance-Materials'}, {'job_title': 'Chemist', 'company': 'Octapharma'}, {'job_title': 'Chemist', 'company': 'St.-Joseph-Medical-Center'}, {'job_title': 'Chemist', 'company': 'Huntsman'}, {'job_title': 'Chemist', 'company': 'The-Kinkaid-School'}, {'job_title': 'Chemist', 'company': 'Zimmerman-Medical-Clinic'}, {'job_title': 'Chemist', 'company': 'Kipp-Houston-Public-Schools'}, {'job_title': 'Chemist', 'company': 'Md-Anderson-Cancer-Center'}, {'job_title': 'Chemist', 'company': 'Devry-University'}, {'job_title': 'Chemist', 'company': 'Pcca'}, {'job_title': 'Chemist', 'company': 'Sysco'}, {'job_title': 'Chemist', 'company': 'Bureau-Veritas'}, {'job_title': 'Chemist', 'company': 'Clinical-Pathology-Laboratories'}, {'job_title': 'Chemist', 'company': "Texas-Children's-Hospital"}, {'job_title': 'Chemist', 'company': 'Yes-Prep-Public-Schools'}, {'job_title': 'Chemist', 'company': 'Blue-Quality-Services'}, {'job_title': 'Chemist', 'company': 'Altus-Baytown-Hospital-2'}, {'job_title': 'Chemist', 'company': 'Nationwide-Laboratory-Partners-LLC'}, {'job_title': 'Chemist', 'company': 'Baylor-College-of-Medicine'}, {'job_title': 'Chemist', 'company': 'Search-Solution-Group'}, {'job_title': 'Chemist', 'company': 'Nalco-Champion%2C-An-Ecolab-Company'}, {'job_title': 'Chemist', 'company': 'The-Princeton-Review'}, {'job_title': 'Chemist', 'company': 'Hexion-Inc.'}, {'job_title': 'Chemist', 'company': 'Houston-Baptist-University'}, {'job_title': 'Chemist', 'company': 'Tech-2000'}, {'job_title': 'Chemist', 'company': 'Adecco-USA-b5c07591'}]
# each=  Conservation
# soup.find(id = 'searchCount') =  <div id="searchCount">Jobs 1 to 10 of 421</div>
# soup.find(id = 'searchCount') =  <class 'bs4.element.Tag'>
# each in all_company_results =  Texas-Children%27s-Hospital
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Cemex
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Blackmon-Mooring-%26-Bmscat
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Raba--kistner
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Lauckgroup-1
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Ceres-Environmental-Services
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Coca--cola-Refreshments
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Windrose-Surveying-%26-Land-Services%2C-LLC
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Special-Counsel
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Dell
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Home-Health-Care-Network-1
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Nci-Building-Systems
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  University-of-Houston
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Service-Masters-2
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Cbre
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Woodridge-Nursing-and-Rehabilitation-%28houston%29
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Starr-Companies
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Servomex
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Pulice-Construction-Inc.
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Basf
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  La-Quinta-Inns-&-Suites
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Severn-Trent-Services
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Kaplan
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  My-Wireless
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Spring-Mobile---AT%26T
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Best-Buy
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Ameresco
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Edp-Renewables-North-America
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Ninyo-%26-Moore
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Memorial-Hermann
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Ch2m
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Robert-Heath-Trucking-Inc.
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Action-Potential-Learning
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Carter-and-Clark
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Mustang-Cat
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Blackmon-Mooring-&-Bmscat
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Chicago-Bridge-%26-Iron-Company
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Ghd
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Shirley-Parsons-LLC-2
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Databank
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  City-of-Houston,-Tx
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Topp-Knotch-Personnel
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Hand-and-Stone
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  CVS-Health
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Atwell
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Groupe-Leader
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Ranger-6b982a83
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Rsh-Energy
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Occidental-Petroleum
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Roto--rooter-Plumbing-%26-Drain-Service
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Latham-%26-Watkins-LLP
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Fairmount-Santrol
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Kleinfelder
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Sodexo
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Celanese
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Healthsouth-Corporation
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Houston-Community-Management-Services---An-Associa-Company
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Stericycle
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Exxonmobil
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Momentum-Staffing
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Surveying-&-Mapping,-LLC-(sam)
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Houston-Zoo
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  The-Hertz-Corporation
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Catholic-Health-Initiatives
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Conserva-Irrigation-1
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Precision-Executive-Search
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Property-Damage-Restoration-Services
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Univar
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  The-Music-Teachers-Network
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Enrud-Resources
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Nrg-Energy
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Latham-&-Watkins-LLP
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  City-of-Pearland%2C-Tx
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  American-Technologies-Inc
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Terracon
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Abacus-Plumbing%2C-Air-Conditioning-%26-Electrical
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Typhoon-Texas
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Engie
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Clean-Line-Energy-Partners
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Mei-LLC
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Baylor-College-of-Medicine
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  H.b.-Fuller
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Roto--rooter-Plumbing-&-Drain-Service
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  American-Midstream-GP-LLC
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  West-Inc.
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Ryder
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Sws-Environmental-Services
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Sheldon-Independent-School-District
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Procare-Therapy-2
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Apex-Companies%2C-LLC
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Supply-Chain---Houston
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Ninyo-&-Moore
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Pbk-Architects
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Lhoist
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Targa-Resources
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Statoil-Gulf-Services-LLC
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Gap-Inc.
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Agile-Premier
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Paragon-Fabricators
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Lonestar-College-System-1
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Nalco-Champion,-An-Ecolab-Company
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Apex-Companies,-LLC
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Jones-and-Carter
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Franklin-Retail-Solutions
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Noble-Energy
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Natural-Pawz-1
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Luxottica
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  UnitedHealth-Group
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Harris-Health-System
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  The-Chemours-Company
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Morningside-Nannies
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Marriott-International,-Inc.
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Compass-Group
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Gullett-&-Associates
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Liberty-Mutual
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Gane-Technology,-Inc.
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Baker-Hughes-Incorporated
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Vans
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Exp
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Clean-Harbors
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Trc-Companies-Inc
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Ieh-Laboratories-1
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Genscape
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Stantec-Consulting
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Brightstar-Care---Sugar-Land%2C-Tx
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Argus-Media
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  St.-Joseph-Medical-Center
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Trinity-Consultants,-Inc.
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Halff-Associates
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Houston-Community-College
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Dbr-Engineering-Consultants,-Inc.
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Tilson-Built-Company
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Nothing-Bundt-Cakes---Sugar-Land
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Hsse
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Ts-Dudley-1
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  JPMorgan-Chase
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Manhattan-Life-Insurance-Company
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  United-Surgical-Partners-International
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Macy's
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  P%26M-Onshore
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  University-of-Houston--downtown
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Chicago-Bridge-&-Iron-Company
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Pape--dawson-Engineers
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Swca-Environmental-Consultants
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Tetra-Tech
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Aspen-Insurance-Holdings
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Jacobs
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Gulbrandsen-Technologies
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# temp_obj_holder['job_title'] =  Conservation
# each in all_company_results =  Set-Environmental
# job_title in all_company_results =  Conservation
# temp_obj_holder =  {'job_title': 'nothing', 'company': 'nothing'}
# ...
# each['geometry']['coordinates'] (-95.3595477, 29.7577534)
# each['geometry']['coordinates'][0] = -95.3595477
# each =  {"geometry": {"coordinates": [-95.64446110000002, 29.6181915], "type": "Point"}, "properties": {"address": "7705 Highway 90-A, Sugar Land, TX 77479, United States", "id": "7f3c2018d2acc84a11d41efcabc7ea95c952638c", "job_title": "Conservation", "name": "Nalco Champion", "photos": [{"height": 729, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/101171909134485641079/photos\">Dennis Arroyo</a>"], "photo_reference": "CoQBdwAAAKnM1BDNByLl98p17MaajKfIJFPcyW9xayW3jaqxj3uqo_InHIVQMQTih3BQdik5vEjFom08iCnbH9azVTeEO7CgvnCz1Od3RIyEm_uHG34wqzle_nbvc4Uu5eONfBsMGfzZAvdp95yoYAxZS6U4JgJbvRrbq2Ev7Eki5swT7ve7EhCyo-6C095pppzVAykPfENOGhSyfY2mtTVDu97e4xBi9jVOjqcGKA", "width": 1296}], "place_id": "ChIJQan0ldTmQIYRNxGlr2hakW0", "rating": 4.9, "reference": "CmRRAAAAyehR5kbmrUJ2qJ7oCLbL9HGgZeB_i9zK6jAkIGocP3Pvwu8IjKJJXm_Qh2aEGTriDISUMAWlsjRHI-JiqU8BQFVfBqVZvaexkNnlTaP3fTVXCErblUMiws29wzl8KGGfEhBINiYRMHHRL_hHzYDkCMH4GhQ32RfUDf0lq067uQFlBg8m-1uMOw", "types": ["point_of_interest", "establishment"]}, "type": "Feature"}
# each['geometry']['coordinates'] (-95.64446110000002, 29.6181915)
# each['geometry']['coordinates'][0] = -95.64446110000002
# each =  {"geometry": {"coordinates": [-95.4487618, 29.54195919999999], "type": "Point"}, "properties": {"address": "3130 FM 521 Rd, Fresno, TX 77545, United States", "id": "d5036c8f10ac52b5b78598637fa714e1b2ca542b", "job_title": "Conservation", "name": "Nalco Champion", "photos": [{"height": 4160, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/104812120607748452359/photos\">Diego Mu\u00f1oz</a>"], "photo_reference": "CoQBdwAAAEN8cZgj1zTyY3TAZ4NJuvmAHIWaDutk9dlp5mu5iQakEyCACd3u5I4xIu9XWaFILN60VitEFJfOtfjdIAEw3BIOoeq7ViHLxe0-JnUsFdHQyAKf8AgNfCQqVY84NmePS-6onyD3S-CE70hFUU_7-kL5oqttJdOpU8YJx4CEx8RYEhD9RIak3ro7AxnfBEYvtcvlGhSJqIziioKmBALOOEzaslRlk7REsw", "width": 3120}], "place_id": "ChIJURevrU3sQIYR44R3O_3yswU", "rating": 5, "reference": "CmRRAAAAeRTGhUPMFZdYHFiJfumkfXmKL0ipbuwgqiRItpHNhvqffhUtiLv3MEcfqGzTon5na2jXNoWiTFQfmHmRFwvkPewWw_xpeXDDtf6z0kWN_7NEimYXRb2HMXxBQjADhov-EhBZeuvLH8WUICu6nfV-9ag-GhSACYOPxYhuRyZZkPBkhG3OT2gXjg", "types": ["point_of_interest", "establishment"]}, "type": "Feature"}
# each['geometry']['coordinates'] (-95.4487618, 29.54195919999999)
# each['geometry']['coordinates'][0] = -95.4487618
# each =  {"geometry": {"coordinates": [-95.40286780000001, 29.7029331], "type": "Point"}, "properties": {"address": "7000 Fannin St #1200, Houston, TX 77030, United States", "id": "93a2701a40d56eeda8265e3004e56297b946a4f9", "job_title": "Conservation", "name": "The University of Texas Health Science Center at Houston", "photos": [{"height": 3450, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/105976331058990070645/photos\">WOLFGANG DEMINO</a>"], "photo_reference": "CoQBdwAAAAVISlN7cbFGPPu0AkcRHamG1GHxwmWzFjQa3H2iiWtPbbHXZtqAqDa7V51JjJG02hDeO253Uy572ahDWg9VGWgviflK9mNXOEpfRtOtwP3A7RkpmgNMIBDABpK5lT5uCzX75rdfWjTQxtWB6OQ380b1lvIkAJ8s_uO23K9AHHzTEhD9A2OZgF5DHeNtDtzrSpKeGhT5eFiqAxnrKIy2rLNib_3wnmU_fw", "width": 4604}], "place_id": "ChIJrYUqx3LAQIYRaIkQm5BzMPs", "rating": 3.9, "reference": "CmRSAAAAXtupOPG1W_zCZMz0dFJFLdT3xRupG3Id4SDw7bzsTZWKAgGN5j-LhbMLxp6pN5HWUCpr6lHgWFb6I1OIB5QnctGRxLaIv5nmQHkWELRjQFnzeBPKE5GKalHjXFMg7IffEhCqW-jI9RHirXI_KDLqwXJzGhS8_XWDqYQDfAHvVxALjYdxv0MVdw", "types": ["hospital", "university", "health", "point_of_interest", "establishment"]}, "type": "Feature"}
# each['geometry']['coordinates'] (-95.40286780000001, 29.7029331)
# each['geometry']['coordinates'][0] = -95.40286780000001
# each =  {"geometry": {"coordinates": [-95.5481478, 29.73449179999999], "type": "Point"}, "properties": {"address": "2925 Briarpark Dr #710, Houston, TX 77042, United States", "id": "ab0b60a79f2c13eb229b7c701aa20bbb526201a4", "job_title": "meteorologist ", "name": "Wilkens Weather Technologies", "photos": [{"height": 800, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/108067520103588366258/photos\">Rachel Wrenn</a>"], "photo_reference": "CoQBdwAAAKsOqEtVLMMDOTTHu70ZiD7MXmki4RQs8DOGAp4wCz4tAkG7DlvoG7PsREzSAcJlW237pedLyYMUGqPtBV4oGrT2auTp6O5qsGx4lkTMzAkpJgbo3BW8ryTmaitomoJhGJnNToILUetmrH1eWY_xLWsVXb-NVsFiVf21GablFJQyEhA-ELYx0aoMjuoOWM0JvkDHGhQ_5Sy1vXkFI-eQfXWaSCp-RlGiQg", "width": 1200}], "place_id": "ChIJaz4msDvDQIYRavam5I_TReg", "rating": 3.9, "reference": "CmRSAAAAS5AtH6dAHVJjQjWxNn6kn2AwCacqsPW0-cr6vPuP44pSFIc3eEEKrjLdUp-WNteNg2BsnV6oX4UqGXcrLfSsJn4SAq2wa3F6Cfh1G3aBOYPWyouBYlfZtXEQdAn4BDJQEhAPSgyoqm5Q-6nHcTY5AzOlGhSBuJOWdpwmrqo5rNGVguSshEJ9YQ", "types": ["point_of_interest", "establishment"]}, "type": "Feature"}
# each['geometry']['coordinates'] (-95.5481478, 29.73449179999999)
# each['geometry']['coordinates'][0] = -95.5481478
# each =  {"geometry": {"coordinates": [-95.11364999999999, 29.555664], "type": "Point"}, "properties": {"address": "1150 Gemini Ave, Houston, TX 77058, United States", "id": "837358ee3e4fecc9bf6053138123b495769d0157", "job_title": "meteorologist ", "name": "Universal Weather and Aviation, Inc. - Trip Support Services", "photos": [{"height": 608, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/100024822646419142787/photos\">Universal Weather and Aviation, Inc. - Trip Support Services</a>"], "photo_reference": "CoQBdwAAAAdwOgrENCjjQfiUWeQWeTzjSFLWgQz-V4V8_ausDYW1cc6ooXmbdLmCuKt9zkapFhuOQJzOe2LW1tcB9NW-my_a6wBlOGyk5_36sVWSxBk2qokzokPiq6xFaDuBJB5Zd24UBs05fKNCDUSnQ8crBLcc9FJ5G75Ncs18E7BqBf0aEhD-B0X0BVpYNjYRoI30uy4oGhRmJTDrnGA92bsP-VMTm7tjG2JGDw", "width": 1080}], "place_id": "ChIJBdImPreXQIYRXX2asNaB7ds", "rating": 3.8, "reference": "CmRSAAAAectDkbnyqpzuw7gioVXSqY03EIvFrO_21NFEgh83pdB9AnpT1bG4G1k_5r6XBDRfZ82EeMGXhopKudoQzmUHriFUvmifw8MdJDhbACNqBl8UIhRgTpOOCNBLlrTsBYiKEhC_omkga554QQH_l6WjQDMgGhSTuBrWjdf7EiufjBDvxQLeWG1DPg", "types": ["point_of_interest", "establishment"]}, "type": "Feature"}
# each['geometry']['coordinates'] (-95.11364999999999, 29.555664)
# each['geometry']['coordinates'][0] = -95.11364999999999
# each =  {"geometry": {"coordinates": [-95.384745, 29.727534], "type": "Point"}, "properties": {"address": "5104 Caroline St, Houston, TX 77004, United States", "id": "4eb60af5582c2593cf2f673892041871c70c0c4d", "job_title": "meteorologist ", "name": "Weather Research Center", "photos": [], "place_id": "ChIJJfqSP3i_QIYR7s2_1O1BH_8", "rating": 3, "reference": "CmRSAAAAhC1xYNZdNKIfu11ern3PinmaTYdtsyEdb1vvQdyVZoKI1CwOg7CNJZm6Axr9RqJs7vMUzkz22dqU_UcBChcdWdGbk_BydwN-4JS6HI_lqVuum7rfkM236LyhOPLO-qgBEhCI9-UsF62nbd2WumkNcb5QGhQ42bnI7iyNItLPln_OeRN4L1P5AA", "types": ["point_of_interest", "establishment"]}, "type": "Feature"}
# each['geometry']['coordinates'] (-95.384745, 29.727534)
# each['geometry']['coordinates'][0] = -95.384745
# each =  {"geometry": {"coordinates": [-95.1097044, 29.5697667], "type": "Point"}, "properties": {"address": "2222 Bay Area Blvd, Houston, TX 77058, United States", "id": "4c65700bf798cd56e51dcde88a8feb5f3b3e367a", "job_title": "meteorologist ", "name": "TASC, An Engility Company", "photos": [], "place_id": "ChIJ6Zo60UicQIYRyFJjF-_VWT0", "rating": "NA", "reference": "CmRRAAAA6IWj9D9JihGCyFBLcJ15zRgYa68xyA96h0IuZCfX1ht0vhsmnvipLCHWJ9GKbq2E3xl80VkJ_K9ETta_iMy8l4TH1RliauJ30rGf4VRZdUm-HqYRVg66fbooxSKTsCfAEhCoQ7gWrPXlL3c006AvkUr5GhQIBdfyaKP_lKZaZB8LtEO1eAnteg", "types": ["point_of_interest", "establishment"]}, "type": "Feature"}
# each['geometry']['coordinates'] (-95.1097044, 29.5697667)
# each['geometry']['coordinates'][0] = -95.1097044
# each =  {"geometry": {"coordinates": [-87.62356559999999, 41.8902768], "type": "Point"}, "properties": {"address": "435 N Michigan Ave #200, Chicago, IL 60611, United States", "id": "91d84f0b7c47521e8d2f37720eb4a5c9fa1d916d", "job_title": "meteorologist ", "name": "Tribune Media", "photos": [{"height": 2048, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/102519153861365089205/photos\">Dimitrios Kapsalis</a>"], "photo_reference": "CoQBdwAAABPKkVmk1UcKVssf-BG2phZGmcKU6YDrlTUNqVJ0OD9UuA_Pfl0fpSetL8U0BfKUPEWEPGHGgWSYA2xz_NloxB2JPCJdeM9buf3cyGnEzRK1wbPweeIM-zUt04ZHlIwPtxl3gaexerjvZiMcgtL5B2-whO4B7jOMUNKCFDGPukWuEhC2Sfs81a73QwEf5LuDrkAGGhS5LYiHTL813pYvav6ybUit1-_LSA", "width": 1833}], "place_id": "ChIJr7zdAKwsDogR83upColIW4Y", "rating": 3, "reference": "CmRSAAAAQhWxHXBT-p1MFSWWFVHjoV_PlZNHYMBGJNAQId0hWSk5genhSX5J0HLSRQJKS9Soa2vWJivGpQfGHgZ5vNuWH_kvUs3GDXIuK-rnNYSM8YNIan4X9L5SPxq3onnKj-zBEhAWuUw__83IhEwCc3rn4eOOGhQ6ufBhwB_5w9MVA9k2eQSH1qUUXw", "types": ["point_of_interest", "establishment"]}, "type": "Feature"}
# each['geometry']['coordinates'] (-87.62356559999999, 41.8902768)
# each['geometry']['coordinates'][0] = -87.62356559999999
# each =  {"geometry": {"coordinates": [-95.4626432, 29.74543], "type": "Point"}, "properties": {"address": "1990 Post Oak Blvd #2300, Houston, TX 77056, United States", "id": "f72dc3e392e287f684950a8edcb544dad94cbd2c", "job_title": "meteorologist ", "name": "Cox Media Group Houston - 93Q", "photos": [{"height": 2988, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/109245492362864624641/photos\">Carlos Rueda</a>"], "photo_reference": "CoQBdwAAAPHhWhCtv7ZH2VcxmECXdA_tBz-Uh-sJ1qfo_QY8BxNI2ymTXaKDUTHovqCFguhRRhwaOYeQVeMHy9SOdNz1wAppsKtz7AJPWtYDN72MG-_9ljBilfIHDr0YPVYZ7YbBnPLXukgzwlFtjDBD605hEmOI4ANdrTtLX4QoD7VcVFChEhC9_R9ZvKQAoufdr9VsE64rGhRhz2oyB_8365n3cVMgM14WkrcOCQ", "width": 5312}], "place_id": "ChIJ3aHZ5mnBQIYR4wyD_Ylq1-k", "rating": 4, "reference": "CmRSAAAAoJM69QSQcCZfAY7GarmZmZiQY8iXDK6GDp5kJTOA30NyrAgE6vWyDwAFEoF2l-l0BN7lXGHa2zb7KPzwGuvtfmY0dGbfbnuZ-NcKKEmAdWH5J0X0G5K-u-EeZ8dT1ThUEhCAd94X6fLRtiMq9SL9OiUgGhTZQD-pZ4L466gMoXw1T27zn4jpoA", "types": ["point_of_interest", "establishment"]}, "type": "Feature"}
# each['geometry']['coordinates'] (-95.4626432, 29.74543)
# each['geometry']['coordinates'][0] = -95.4626432
# each =  {"geometry": {"coordinates": [-95.3712078, 29.7590224], "type": "Point"}, "properties": {"address": "1100 Bagby St, Houston, TX 77002, United States", "id": "c97d02c9a29112d01b36ec83bddb838ee36bac4d", "job_title": "meteorologist ", "name": "The Heritage Society", "photos": [{"height": 391, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/103103702851351534796/photos\">The Heritage Society</a>"], "photo_reference": "CoQBdwAAANvrT3w9Vr6ryoaZJxMf0bSrCLzT89qfWhKVuMTIZY_WgOFKk8pxV7iBE8ryi1K4JJIDGMmrzGYa0AGb9gAI3kIHqeBEyAeTChes4_bSC2woXPGYKTSBDYFDQDJ5rEIUeYRbTWcnyYpPyI_VQpiW4evIcsgL849evx7sa1XvJ2jBEhB27VHQz84i-VgbYoJD-JrSGhSfnjyTI70w5lN3sabx1Ms-Lbo0VQ", "width": 388}], "place_id": "ChIJz4ChNji_QIYRuPoNXW9w520", "rating": 4.4, "reference": "CmRRAAAAoEn5EvYTwkZJjJb0N5sOMchCWmbgXMvDbM_E5W0gYrrKmjjMrZrnjpwHpw4cnxsIok_EKRygNmNFjO__xtV-HKiRDJUPC0v6s-k8d_Xdb9j_nQPyIkp9mFddE1sDzH4GEhBC1E0sYgIrALV4jEo5o8fvGhRWrVXKdapyNjUgV7Tzn4PlfqaYXQ", "types": ["museum", "point_of_interest", "establishment"]}, "type": "Feature"}
# each['geometry']['coordinates'] (-95.3712078, 29.7590224)
# each['geometry']['coordinates'][0] = -95.3712078
# each =  {"geometry": {"coordinates": [-95.42932479999999, 29.7259696], "type": "Point"}, "properties": {"address": "3310 Bissonnet St, Houston, TX 77005, United States", "id": "fa481cef09023e2007970bc05c7c834e3753f74e", "job_title": "meteorologist ", "name": "ABC 13 KTRK-TV", "photos": [], "place_id": "ChIJPwXfeQzBQIYRPxpShrzYFMM", "rating": 4.4, "reference": "CmRSAAAAFCiEKW79THlfrodzKvwEeeA-r2yCv2FQwuqwzbaxcUdbKQfF06OlATNm76lePQST7NMim1bM8AiCnve89MOWVz97cmECk4oM9X7hUB8Zz8kDcvM3prnKfDJk8yZ2PqGPEhB5iaBAtemlzxkw1m-4DrxQGhSGzmEviPdFej9qyL-zoWZ4w8PYVg", "types": ["point_of_interest", "establishment"]}, "type": "Feature"}
# each['geometry']['coordinates'] (-95.42932479999999, 29.7259696)
# each['geometry']['coordinates'][0] = -95.42932479999999
# finished the function createFeatureCollection and slimmed featureList is slimmed_featList [{"geometry": {"coordinates": [-95.40157669999999, 29.7078637], "type": "Point"}, "properties": {"address": "6621 Fannin St, Houston, TX 77030, United States", "id": "21887ef88f472e1de7d6e166df61462388909130", "job_title": "Chemist", "name": "Texas Children's Hospital", "photos": [{"height": 3264, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/110628852257066465334/photos\">Rafida Alkaabi</a>"], "photo_reference": "CoQBdwAAAA2Rq3RqUeVhl5UqGk-HDZNTsF95J72KYuBW0_p6OdRW0kynRr-GJ2qPtK1HAww4_TeT7SWbjS2slMhVrW4DpqiVuM_9HOYvl2rhlGZg5z4LD92mD-0bSWiAW4k36ctBf26wPTiVBs3RnhPvlKUSFl2V7IP1l_MXtwD3KX9lQ-BFEhB4JAaoTMtrXuICMjoSnULdGhRRv8pq8P3XV8S64-HnOfeWtZIe4w", "width": 2448}], "place_id": "ChIJlfANKnLAQIYRNm9fma-7eQs", "rating": 3.8, "reference": "CmRRAAAAUSII9_hcznTT9JkXEFdppfcgd9PJPfNoP9LrvBL3CbZn0hzc0m9MzX_ooMXYlAXO5TMDqWvBJs7yj-iUaFL2-jSXvqLTd0j-pptOO1JnCfO-n9t603B5DFeui3xOMHIYEhAEm_kX-wv3h6OWgYOlMaSLGhRmxMLaYrJDcsfp3ZkeHdOtX8rw8g", "types": ["hospital", "doctor", "health", "point_of_interest", "establishment"]}, "type": "Feature"}, {"geometry": {"coordinates": [-95.56136699999999, 29.838261], "type": "Point"}, "properties": {"address": "11025 Equity Dr, Houston, TX 77041, United States", "id": "9403f26049c5776732122422879a624c8ab25dde", "job_title": "Chemist", "name": "Chamberlain College of Nursing", "photos": [{"height": 536, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/111289430325950022552/photos\">Chamberlain College of Nursing</a>"], "photo_reference": "CoQBdwAAACR3h7E1Kx4Yok5SJx9aAd5aZB2jixAAEkW3HB7H2l0LVpzAyX-AuY9zSUeRV3yjxR-WtYxbpyj9NGCGf_X3Ks-hx0cGKnS8UIkiD0IlzIeW-NlVAV2C4RrHjy1IeU_SlqMMVXv-2Rm6_RheUhyibBKGQHkelQT0cEtYGBfH5D5OEhAcZR5NdWindLVIqMIk4GTgGhTjX2pQpRRMNTeCKCGKaMBl-F5Cog", "width": 953}], "place_id": "ChIJX66HNkvFQIYR1teKn_jUpnc", "rating": 4.4, "reference": "CmRRAAAAf72YTJ7ei944GfGt8xeg-knf0IA_raDNHacwT_fSRWYwksJigFFBQfVwDlO4J-mFYwOeibdwIG7f75rm1TLEAfWgL1XPNZfC1c2Mhud6fnK5-SOQ3ZQguJm7UIOQwX0xEhCA81Zna-lyW_MECbrcZrrJGhSJ_0NKPK_fu268I79wVQFXOA4cYQ", "types": ["university", "school", "point_of_interest", "establishment"]}, "type": "Feature"}, {"geometry": {"coordinates": [-95.2795793, 29.7870046], "type": "Point"}, "properties": {"address": "223 McCarty St, Houston, TX 77029, United States", "id": "5dd22533db632edb7b6bd8d43659cee9e0153e7b", "job_title": "Chemist", "name": "O'Rourke Petroleum Products", "photos": [{"height": 2988, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/117048453861187786040/photos\">Hope Morales</a>"], "photo_reference": "CoQBdwAAAAq44S9JYjZ8pGrYM-FHBsZhPJbqyD_LwraqplilJfqekO-MxSec1xLQ6C7jg-4BY8AJoH6pnjLhKlGU6B6G2SRD7hWLIjjrFXmvEAnK5-7WcGd2aHjrhPMhFLWKgtzdXZYiMJDWBO526fLgAQugG65mxa10qjLBNgJG6-LCTNedEhCUPhD4945ljqVRTm91AD8SGhQpRZy5QLz3NFuzKOXaJ4LlXajWhA", "width": 3984}], "place_id": "ChIJlz2S8Y-7QIYRfYAJ0MmNKMs", "rating": 5, "reference": "CmRSAAAA29BLQsjPnjqM35LNT_1MlgLjRh0fTwg2NsXONAviGxLwYNdHSgsxvgXs2KnZYF_iSvx0Z6hgF_2vPYDZNdTjhJzr9Agr8g1OSZ4vzAep38oHg8AXh3m8O0EPOekBMjXyEhB62gJ6IxqjFjX4KIkREbDXGhQBAmksLnF4ME38PD1tsQ9uhvyeQQ", "types": ["store", "point_of_interest", "establishment"]}, "type": "Feature"}, {"geometry": {"coordinates": [-94.9764522, 29.7345406], "type": "Point"}, "properties": {"address": "200 Lee Dr, Baytown, TX 77520, United States", "id": "b39dcd6b64e00fbefeb496c60f5a8887921c8efd", "job_title": "Chemist", "name": "Lee College", "photos": [{"height": 1360, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/115635721259111917781/photos\">Lee College</a>"], "photo_reference": "CoQBdwAAAMruCS8Ad9yHuui3ETbwcXgC9hLsr5QY9Js41LtZsG2OYIVH9dr327wIIOphizw0L8DFp8hKA2PGG_-kGm7HcxiUeXUIzm1bArt0vmSirSNrMLNiybcg8g-HYs0X371b1vHiUe4uuhyxhhupCvxQe4AJXMW--vXmdeC7OHqoh8-oEhAeMW_NooeHLIYttMcAKLIMGhQWL0BckAGhgtCU453GWD4eIPFSvQ", "width": 2048}], "place_id": "ChIJTXeoIdZdP4YRirpOD6GePVI", "rating": 4.5, "reference": "CmRRA ...
# got to the function convertFeatureCollectionToGeoJSON
